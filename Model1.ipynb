# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# 2024-06-19 20:39:51.396807: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
apt_cutoff = application_df['APPLICATION_TYPE'].value_counts() > 10
application_types_to_replace = list(apt_cutoff[apt_cutoff == False].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# T12         27
# T2          16
# Other       11
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cls_cutoff = (application_df['CLASSIFICATION'].value_counts() >= 50) & (application_df['CLASSIFICATION'].value_counts() < 1000)
classifications_to_replace = list(cls_cutoff[cls_cutoff == True].index)


# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C2561        1
# C1245        1
# C8210        1
# C2150        1
# Name: count, Length: 62, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies = pd.get_dummies(application_df.drop(columns='IS_SUCCESSFUL'), dtype=int)
[x for x in dummies.columns]
# Out:
# ['STATUS',
#  'ASK_AMT',
#  'APPLICATION_TYPE_Other',
#  'APPLICATION_TYPE_T10',
#  'APPLICATION_TYPE_T12',
#  'APPLICATION_TYPE_T13',
#  'APPLICATION_TYPE_T19',
#  'APPLICATION_TYPE_T2',
#  'APPLICATION_TYPE_T3',
#  'APPLICATION_TYPE_T4',
#  'APPLICATION_TYPE_T5',
#  'APPLICATION_TYPE_T6',
#  'APPLICATION_TYPE_T7',
#  'APPLICATION_TYPE_T8',
#  'APPLICATION_TYPE_T9',
#  'AFFILIATION_CompanySponsored',
#  'AFFILIATION_Family/Parent',
#  'AFFILIATION_Independent',
#  'AFFILIATION_National',
#  'AFFILIATION_Other',
#  'AFFILIATION_Regional',
#  'CLASSIFICATION_C0',
#  'CLASSIFICATION_C1000',
#  'CLASSIFICATION_C1200',
#  'CLASSIFICATION_C1230',
#  'CLASSIFICATION_C1234',
#  'CLASSIFICATION_C1235',
#  'CLASSIFICATION_C1236',
#  'CLASSIFICATION_C1237',
#  'CLASSIFICATION_C1238',
#  'CLASSIFICATION_C1240',
#  'CLASSIFICATION_C1245',
#  'CLASSIFICATION_C1246',
#  'CLASSIFICATION_C1248',
#  'CLASSIFICATION_C1250',
#  'CLASSIFICATION_C1256',
#  'CLASSIFICATION_C1257',
#  'CLASSIFICATION_C1260',
#  'CLASSIFICATION_C1267',
#  'CLASSIFICATION_C1278',
#  'CLASSIFICATION_C1283',
#  'CLASSIFICATION_C1370',
#  'CLASSIFICATION_C1400',
#  'CLASSIFICATION_C1500',
#  'CLASSIFICATION_C1570',
#  'CLASSIFICATION_C1580',
#  'CLASSIFICATION_C1600',
#  'CLASSIFICATION_C1720',
#  'CLASSIFICATION_C1728',
#  'CLASSIFICATION_C1732',
#  'CLASSIFICATION_C1800',
#  'CLASSIFICATION_C1820',
#  'CLASSIFICATION_C1900',
#  'CLASSIFICATION_C2000',
#  'CLASSIFICATION_C2100',
#  'CLASSIFICATION_C2150',
#  'CLASSIFICATION_C2170',
#  'CLASSIFICATION_C2190',
#  'CLASSIFICATION_C2300',
#  'CLASSIFICATION_C2380',
#  'CLASSIFICATION_C2400',
#  'CLASSIFICATION_C2500',
#  'CLASSIFICATION_C2561',
#  'CLASSIFICATION_C2570',
#  'CLASSIFICATION_C2600',
#  'CLASSIFICATION_C2710',
#  'CLASSIFICATION_C3000',
#  'CLASSIFICATION_C3200',
#  'CLASSIFICATION_C3700',
#  'CLASSIFICATION_C4100',
#  'CLASSIFICATION_C4120',
#  'CLASSIFICATION_C4200',
#  'CLASSIFICATION_C4500',
#  'CLASSIFICATION_C5200',
#  'CLASSIFICATION_C6000',
#  'CLASSIFICATION_C6100',
#  'CLASSIFICATION_C7120',
#  'CLASSIFICATION_C7200',
#  'CLASSIFICATION_C7210',
#  'CLASSIFICATION_C8000',
#  'CLASSIFICATION_C8200',
#  'CLASSIFICATION_C8210',
#  'CLASSIFICATION_Other',
#  'USE_CASE_CommunityServ',
#  'USE_CASE_Heathcare',
#  'USE_CASE_Other',
#  'USE_CASE_Preservation',
#  'USE_CASE_ProductDev',
#  'ORGANIZATION_Association',
#  'ORGANIZATION_Co-operative',
#  'ORGANIZATION_Corporation',
#  'ORGANIZATION_Trust',
#  'INCOME_AMT_0',
#  'INCOME_AMT_1-9999',
#  'INCOME_AMT_10000-24999',
#  'INCOME_AMT_100000-499999',
#  'INCOME_AMT_10M-50M',
#  'INCOME_AMT_1M-5M',
#  'INCOME_AMT_25000-99999',
#  'INCOME_AMT_50M+',
#  'INCOME_AMT_5M-10M',
#  'SPECIAL_CONSIDERATIONS_N',
#  'SPECIAL_CONSIDERATIONS_Y']

# %%
# Split our preprocessed data into our features and target arrays
X = dummies
y = application_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
(X_train, X_test, y_train, y_test) = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=dummies.shape[1]))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 520
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 556
# Trainable params: 556
# Non-trainable params: 0
# _________________________________________________________________
# 2024-06-19 20:45:29.136057: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit = nn.fit(X_train_scaled, y_train, epochs=150)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 1s 648us/step - loss: 0.6232 - accuracy: 0.6820
# Epoch 2/150
# 804/804 [==============================] - 1s 635us/step - loss: 0.5792 - accuracy: 0.7212
# Epoch 3/150
# 804/804 [==============================] - 0s 619us/step - loss: 0.5701 - accuracy: 0.7219
# Epoch 4/150
# 804/804 [==============================] - 1s 665us/step - loss: 0.5657 - accuracy: 0.7231
# Epoch 5/150
# 804/804 [==============================] - 1s 624us/step - loss: 0.5627 - accuracy: 0.7241
# Epoch 6/150
# 804/804 [==============================] - 1s 633us/step - loss: 0.5615 - accuracy: 0.7252
# Epoch 7/150
# 804/804 [==============================] - 1s 629us/step - loss: 0.5602 - accuracy: 0.7266
# Epoch 8/150
# 804/804 [==============================] - 1s 659us/step - loss: 0.5590 - accuracy: 0.7263
# Epoch 9/150
# 804/804 [==============================] - 1s 672us/step - loss: 0.5582 - accuracy: 0.7273
# Epoch 10/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5576 - accuracy: 0.7284
# Epoch 11/150
# 804/804 [==============================] - 1s 632us/step - loss: 0.5573 - accuracy: 0.7288
# Epoch 12/150
# 804/804 [==============================] - 1s 682us/step - loss: 0.5568 - accuracy: 0.7283
# Epoch 13/150
# 804/804 [==============================] - 1s 636us/step - loss: 0.5559 - accuracy: 0.7286
# Epoch 14/150
# 804/804 [==============================] - 1s 744us/step - loss: 0.5560 - accuracy: 0.7283
# Epoch 15/150
# 804/804 [==============================] - 1s 706us/step - loss: 0.5559 - accuracy: 0.7299
# Epoch 16/150
# 804/804 [==============================] - 1s 645us/step - loss: 0.5556 - accuracy: 0.7285
# Epoch 17/150
# 804/804 [==============================] - 1s 650us/step - loss: 0.5555 - accuracy: 0.7297
# Epoch 18/150
# 804/804 [==============================] - 0s 619us/step - loss: 0.5554 - accuracy: 0.7298
# Epoch 19/150
# 804/804 [==============================] - 1s 648us/step - loss: 0.5551 - accuracy: 0.7296
# Epoch 20/150
# 804/804 [==============================] - 1s 626us/step - loss: 0.5547 - accuracy: 0.7302
# Epoch 21/150
# 804/804 [==============================] - 0s 618us/step - loss: 0.5530 - accuracy: 0.7302
# Epoch 22/150
# 804/804 [==============================] - 1s 624us/step - loss: 0.5527 - accuracy: 0.7302
# Epoch 23/150
# 804/804 [==============================] - 1s 641us/step - loss: 0.5526 - accuracy: 0.7311
# Epoch 24/150
# 804/804 [==============================] - 1s 627us/step - loss: 0.5524 - accuracy: 0.7290
# Epoch 25/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5519 - accuracy: 0.7297
# Epoch 26/150
# 804/804 [==============================] - 1s 630us/step - loss: 0.5520 - accuracy: 0.7289
# Epoch 27/150
# 804/804 [==============================] - 1s 639us/step - loss: 0.5518 - accuracy: 0.7286
# Epoch 28/150
# 804/804 [==============================] - 1s 658us/step - loss: 0.5519 - accuracy: 0.7304
# Epoch 29/150
# 804/804 [==============================] - 1s 623us/step - loss: 0.5516 - accuracy: 0.7294
# Epoch 30/150
# 804/804 [==============================] - 1s 635us/step - loss: 0.5517 - accuracy: 0.7292
# Epoch 31/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5514 - accuracy: 0.7306
# Epoch 32/150
# 804/804 [==============================] - 1s 635us/step - loss: 0.5515 - accuracy: 0.7306
# Epoch 33/150
# 804/804 [==============================] - 1s 657us/step - loss: 0.5512 - accuracy: 0.7304
# Epoch 34/150
# 804/804 [==============================] - 1s 628us/step - loss: 0.5511 - accuracy: 0.7297
# Epoch 35/150
# 804/804 [==============================] - 1s 624us/step - loss: 0.5510 - accuracy: 0.7299
# Epoch 36/150
# 804/804 [==============================] - 1s 655us/step - loss: 0.5511 - accuracy: 0.7304
# Epoch 37/150
# 804/804 [==============================] - 1s 670us/step - loss: 0.5509 - accuracy: 0.7306
# Epoch 38/150
# 804/804 [==============================] - 1s 673us/step - loss: 0.5509 - accuracy: 0.7308
# Epoch 39/150
# 804/804 [==============================] - 1s 673us/step - loss: 0.5503 - accuracy: 0.7304
# Epoch 40/150
# 804/804 [==============================] - 1s 676us/step - loss: 0.5502 - accuracy: 0.7310
# Epoch 41/150
# 804/804 [==============================] - 1s 661us/step - loss: 0.5502 - accuracy: 0.7317
# Epoch 42/150
# 804/804 [==============================] - 1s 660us/step - loss: 0.5501 - accuracy: 0.7304
# Epoch 43/150
# 804/804 [==============================] - 1s 931us/step - loss: 0.5501 - accuracy: 0.7307
# Epoch 44/150
# 804/804 [==============================] - 1s 656us/step - loss: 0.5499 - accuracy: 0.7313
# Epoch 45/150
# 804/804 [==============================] - 1s 639us/step - loss: 0.5494 - accuracy: 0.7323
# Epoch 46/150
# 804/804 [==============================] - 1s 669us/step - loss: 0.5496 - accuracy: 0.7313
# Epoch 47/150
# 804/804 [==============================] - 1s 633us/step - loss: 0.5497 - accuracy: 0.7308
# Epoch 48/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5493 - accuracy: 0.7314
# Epoch 49/150
# 804/804 [==============================] - 1s 637us/step - loss: 0.5494 - accuracy: 0.7312
# Epoch 50/150
# 804/804 [==============================] - 1s 644us/step - loss: 0.5495 - accuracy: 0.7316
# Epoch 51/150
# 804/804 [==============================] - 1s 660us/step - loss: 0.5495 - accuracy: 0.7314
# Epoch 52/150
# 804/804 [==============================] - 1s 623us/step - loss: 0.5491 - accuracy: 0.7315
# Epoch 53/150
# 804/804 [==============================] - 0s 616us/step - loss: 0.5494 - accuracy: 0.7314
# Epoch 54/150
# 804/804 [==============================] - 1s 629us/step - loss: 0.5492 - accuracy: 0.7317
# Epoch 55/150
# 804/804 [==============================] - 1s 632us/step - loss: 0.5490 - accuracy: 0.7302
# Epoch 56/150
# 804/804 [==============================] - 1s 653us/step - loss: 0.5490 - accuracy: 0.7311
# Epoch 57/150
# 804/804 [==============================] - 1s 632us/step - loss: 0.5491 - accuracy: 0.7317
# Epoch 58/150
# 804/804 [==============================] - 1s 636us/step - loss: 0.5490 - accuracy: 0.7318
# Epoch 59/150
# 804/804 [==============================] - 1s 642us/step - loss: 0.5487 - accuracy: 0.7311
# Epoch 60/150
# 804/804 [==============================] - 1s 653us/step - loss: 0.5489 - accuracy: 0.7308
# Epoch 61/150
# 804/804 [==============================] - 1s 634us/step - loss: 0.5487 - accuracy: 0.7316
# Epoch 62/150
# 804/804 [==============================] - 1s 632us/step - loss: 0.5488 - accuracy: 0.7311
# Epoch 63/150
# 804/804 [==============================] - 1s 660us/step - loss: 0.5489 - accuracy: 0.7307
# Epoch 64/150
# 804/804 [==============================] - 1s 632us/step - loss: 0.5486 - accuracy: 0.7321
# Epoch 65/150
# 804/804 [==============================] - 1s 658us/step - loss: 0.5484 - accuracy: 0.7314
# Epoch 66/150
# 804/804 [==============================] - 1s 637us/step - loss: 0.5487 - accuracy: 0.7317
# Epoch 67/150
# 804/804 [==============================] - 1s 648us/step - loss: 0.5483 - accuracy: 0.7305
# Epoch 68/150
# 804/804 [==============================] - 1s 637us/step - loss: 0.5484 - accuracy: 0.7316
# Epoch 69/150
# 804/804 [==============================] - 1s 660us/step - loss: 0.5485 - accuracy: 0.7298
# Epoch 70/150
# 804/804 [==============================] - 1s 640us/step - loss: 0.5484 - accuracy: 0.7311
# Epoch 71/150
# 804/804 [==============================] - 1s 636us/step - loss: 0.5482 - accuracy: 0.7317
# Epoch 72/150
# 804/804 [==============================] - 1s 646us/step - loss: 0.5483 - accuracy: 0.7308
# Epoch 73/150
# 804/804 [==============================] - 1s 650us/step - loss: 0.5484 - accuracy: 0.7314
# Epoch 74/150
# 804/804 [==============================] - 1s 687us/step - loss: 0.5484 - accuracy: 0.7316
# Epoch 75/150
# 804/804 [==============================] - 1s 630us/step - loss: 0.5484 - accuracy: 0.7313
# Epoch 76/150
# 804/804 [==============================] - 1s 852us/step - loss: 0.5480 - accuracy: 0.7315
# Epoch 77/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7315
# Epoch 78/150
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5482 - accuracy: 0.7320
# Epoch 79/150
# 804/804 [==============================] - 1s 751us/step - loss: 0.5481 - accuracy: 0.7318
# Epoch 80/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5481 - accuracy: 0.7323
# Epoch 81/150
# 804/804 [==============================] - 1s 660us/step - loss: 0.5478 - accuracy: 0.7312
# Epoch 82/150
# 804/804 [==============================] - 1s 632us/step - loss: 0.5480 - accuracy: 0.7310
# Epoch 83/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5484 - accuracy: 0.7315
# Epoch 84/150
# 804/804 [==============================] - 1s 635us/step - loss: 0.5480 - accuracy: 0.7316
# Epoch 85/150
# 804/804 [==============================] - 1s 632us/step - loss: 0.5483 - accuracy: 0.7318
# Epoch 86/150
# 804/804 [==============================] - 1s 662us/step - loss: 0.5480 - accuracy: 0.7318
# Epoch 87/150
# 804/804 [==============================] - 1s 636us/step - loss: 0.5480 - accuracy: 0.7328
# Epoch 88/150
# 804/804 [==============================] - 1s 642us/step - loss: 0.5481 - accuracy: 0.7315
# Epoch 89/150
# 804/804 [==============================] - 1s 634us/step - loss: 0.5480 - accuracy: 0.7315
# Epoch 90/150
# 804/804 [==============================] - 1s 662us/step - loss: 0.5478 - accuracy: 0.7310
# Epoch 91/150
# 804/804 [==============================] - 1s 643us/step - loss: 0.5481 - accuracy: 0.7306
# Epoch 92/150
# 804/804 [==============================] - 1s 643us/step - loss: 0.5479 - accuracy: 0.7325
# Epoch 93/150
# 804/804 [==============================] - 1s 624us/step - loss: 0.5479 - accuracy: 0.7320
# Epoch 94/150
# 804/804 [==============================] - 1s 654us/step - loss: 0.5481 - accuracy: 0.7315
# Epoch 95/150
# 804/804 [==============================] - 0s 610us/step - loss: 0.5475 - accuracy: 0.7305
# Epoch 96/150
# 804/804 [==============================] - 0s 619us/step - loss: 0.5479 - accuracy: 0.7314
# Epoch 97/150
# 804/804 [==============================] - 1s 624us/step - loss: 0.5479 - accuracy: 0.7318
# Epoch 98/150
# 804/804 [==============================] - 1s 623us/step - loss: 0.5479 - accuracy: 0.7315
# Epoch 99/150
# 804/804 [==============================] - 1s 638us/step - loss: 0.5478 - accuracy: 0.7317
# Epoch 100/150
# 804/804 [==============================] - 1s 621us/step - loss: 0.5479 - accuracy: 0.7312
# Epoch 101/150
# 804/804 [==============================] - 1s 625us/step - loss: 0.5478 - accuracy: 0.7308
# Epoch 102/150
# 804/804 [==============================] - 1s 622us/step - loss: 0.5477 - accuracy: 0.7321
# Epoch 103/150
# 804/804 [==============================] - 1s 637us/step - loss: 0.5479 - accuracy: 0.7320
# Epoch 104/150
# 804/804 [==============================] - 1s 670us/step - loss: 0.5478 - accuracy: 0.7315
# Epoch 105/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5479 - accuracy: 0.7327
# Epoch 106/150
# 804/804 [==============================] - 1s 633us/step - loss: 0.5479 - accuracy: 0.7318
# Epoch 107/150
# 804/804 [==============================] - 1s 637us/step - loss: 0.5479 - accuracy: 0.7320
# Epoch 108/150
# 804/804 [==============================] - 1s 667us/step - loss: 0.5478 - accuracy: 0.7325
# Epoch 109/150
# 804/804 [==============================] - 1s 630us/step - loss: 0.5477 - accuracy: 0.7311
# Epoch 110/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5478 - accuracy: 0.7317
# Epoch 111/150
# 804/804 [==============================] - 1s 629us/step - loss: 0.5479 - accuracy: 0.7323
# Epoch 112/150
# 804/804 [==============================] - 1s 632us/step - loss: 0.5475 - accuracy: 0.7323
# Epoch 113/150
# 804/804 [==============================] - 1s 653us/step - loss: 0.5479 - accuracy: 0.7323
# Epoch 114/150
# 804/804 [==============================] - 1s 629us/step - loss: 0.5478 - accuracy: 0.7320
# Epoch 115/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5477 - accuracy: 0.7314
# Epoch 116/150
# 804/804 [==============================] - 1s 630us/step - loss: 0.5479 - accuracy: 0.7310
# Epoch 117/150
# 804/804 [==============================] - 1s 637us/step - loss: 0.5476 - accuracy: 0.7319
# Epoch 118/150
# 804/804 [==============================] - 1s 667us/step - loss: 0.5479 - accuracy: 0.7318
# Epoch 119/150
# 804/804 [==============================] - 1s 634us/step - loss: 0.5476 - accuracy: 0.7323
# Epoch 120/150
# 804/804 [==============================] - 1s 635us/step - loss: 0.5477 - accuracy: 0.7321
# Epoch 121/150
# 804/804 [==============================] - 1s 626us/step - loss: 0.5477 - accuracy: 0.7318
# Epoch 122/150
# 804/804 [==============================] - 1s 655us/step - loss: 0.5475 - accuracy: 0.7313
# Epoch 123/150
# 804/804 [==============================] - 1s 626us/step - loss: 0.5477 - accuracy: 0.7317
# Epoch 124/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5476 - accuracy: 0.7325
# Epoch 125/150
# 804/804 [==============================] - 1s 633us/step - loss: 0.5477 - accuracy: 0.7320
# Epoch 126/150
# 804/804 [==============================] - 1s 629us/step - loss: 0.5476 - accuracy: 0.7319
# Epoch 127/150
# 804/804 [==============================] - 1s 656us/step - loss: 0.5476 - accuracy: 0.7324
# Epoch 128/150
# 804/804 [==============================] - 1s 690us/step - loss: 0.5476 - accuracy: 0.7313
# Epoch 129/150
# 804/804 [==============================] - 1s 672us/step - loss: 0.5477 - accuracy: 0.7311
# Epoch 130/150
# 804/804 [==============================] - 1s 687us/step - loss: 0.5477 - accuracy: 0.7317
# Epoch 131/150
# 804/804 [==============================] - 1s 661us/step - loss: 0.5475 - accuracy: 0.7313
# Epoch 132/150
# 804/804 [==============================] - 1s 665us/step - loss: 0.5476 - accuracy: 0.7308
# Epoch 133/150
# 804/804 [==============================] - 1s 663us/step - loss: 0.5479 - accuracy: 0.7318
# Epoch 134/150
# 804/804 [==============================] - 1s 633us/step - loss: 0.5477 - accuracy: 0.7312
# Epoch 135/150
# 804/804 [==============================] - 1s 668us/step - loss: 0.5476 - accuracy: 0.7318
# Epoch 136/150
# 804/804 [==============================] - 0s 618us/step - loss: 0.5475 - accuracy: 0.7319
# Epoch 137/150
# 804/804 [==============================] - 0s 617us/step - loss: 0.5474 - accuracy: 0.7316
# Epoch 138/150
# 804/804 [==============================] - 0s 598us/step - loss: 0.5473 - accuracy: 0.7328
# Epoch 139/150
# 804/804 [==============================] - 1s 626us/step - loss: 0.5476 - accuracy: 0.7315
# Epoch 140/150
# 804/804 [==============================] - 0s 619us/step - loss: 0.5476 - accuracy: 0.7313
# Epoch 141/150
# 804/804 [==============================] - 1s 631us/step - loss: 0.5477 - accuracy: 0.7317
# Epoch 142/150
# 804/804 [==============================] - 1s 625us/step - loss: 0.5474 - accuracy: 0.7321
# Epoch 143/150
# 804/804 [==============================] - 1s 635us/step - loss: 0.5475 - accuracy: 0.7316
# Epoch 144/150
# 804/804 [==============================] - 1s 651us/step - loss: 0.5476 - accuracy: 0.7319
# Epoch 145/150
# 804/804 [==============================] - 1s 624us/step - loss: 0.5476 - accuracy: 0.7318
# Epoch 146/150
# 804/804 [==============================] - 1s 626us/step - loss: 0.5476 - accuracy: 0.7324
# Epoch 147/150
# 804/804 [==============================] - 1s 626us/step - loss: 0.5475 - accuracy: 0.7324
# Epoch 148/150
# 804/804 [==============================] - 1s 651us/step - loss: 0.5475 - accuracy: 0.7323
# Epoch 149/150
# 804/804 [==============================] - 1s 623us/step - loss: 0.5474 - accuracy: 0.7326
# Epoch 150/150
# 804/804 [==============================] - 0s 621us/step - loss: 0.5475 - accuracy: 0.7317

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5626 - accuracy: 0.7251 - 221ms/epoch - 825us/step
# Loss: 0.5626432299613953, Accuracy: 0.7251312136650085

# %%
# Export our model to HDF5 file
nn.save_weights('nn1.hdf5')
